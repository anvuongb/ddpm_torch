# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5, 0.001)

def sigmoid(x):
    return 1/(1+np.exp(-x))

def swiss(x):
    return x*sigmoid(x)

# %%
plt.plot(sigmoid(x))
plt.show()
plt.plot(swiss(x))
plt.show()
